# %%
import os
import random
from pathlib import Path

# %%
os.chdir('/home/shehroz/Desktop/Seminar/data_ct/COVID')
print(os.getcwd())
# Out:
# /home/shehroz/Desktop/Seminar/data_ct/COVID

# %%
# write the path
# delete the file
# write the path again
# delete the file

# %%
def deleter():
    path = os.listdir()
    print("the first file is: ")
    print(path[0])
    os.remove(path[0])
    print("The file has been deleted\n")

# %%
for _ in range(1152):
    deleter()
# Out:
# the first file is:
# Covid (403).png
# The file has been deleted
#
# the first file is:
# Covid (987).png
# The file has been deleted
#
# the first file is:
# Covid (790).png
# The file has been deleted
#
# the first file is:
# Covid (1226).png
# The file has been deleted
#
# the first file is:
# Covid (1006).png
# The file has been deleted
#
# the first file is:
# Covid (438).png
# The file has been deleted
#
# the first file is:
# Covid (866).png
# The file has been deleted
#
# the first file is:
# Covid (1237).png
# The file has been deleted
#
# the first file is:
# Covid (1234).png
# The file has been deleted
#
# the first file is:
# Covid (624).png
# The file has been deleted
#
# the first file is:
# Covid (409).png
# The file has been deleted
#
# the first file is:
# Covid (444).png
# The file has been deleted
#
# the first file is:
# Covid (1140).png
# The file has been deleted
#
# the first file is:
# Covid (538).png
# The file has been deleted
#
# the first file is:
# ...

# %%
#change directory to normal
os.chdir('/home/shehroz/Desktop/Seminar/data_ct/non-COVID')
print(os.getcwd())
# Out:
# /home/shehroz/Desktop/Seminar/data_ct/non-COVID

# %%
#check number of pictures in directory
def counter():
    dir_path = os.getcwd()
    print("The directory is ", dir_path)
    count = 0
# Iterate directory
    for path in os.listdir(dir_path):
        # check if current path is a file
        if os.path.isfile(os.path.join(dir_path, path)):
            count += 1
    print('File count:', count)

# %%
for _ in range(1129):
    deleter()
# Out:
# the first file is:
# Non-Covid (966).png
# The file has been deleted
#
# the first file is:
# Non-Covid (1115).png
# The file has been deleted
#
# the first file is:
# Non-Covid (851).png
# The file has been deleted
#
# the first file is:
# Non-Covid (1055).png
# The file has been deleted
#
# the first file is:
# Non-Covid (908).png
# The file has been deleted
#
# the first file is:
# Non-Covid (875).png
# The file has been deleted
#
# the first file is:
# Non-Covid (516).png
# The file has been deleted
#
# the first file is:
# Non-Covid (286).png
# The file has been deleted
#
# the first file is:
# Non-Covid (1092).png
# The file has been deleted
#
# the first file is:
# Non-Covid (1137).png
# The file has been deleted
#
# the first file is:
# Non-Covid (763).png
# The file has been deleted
#
# the first file is:
# Non-Covid (165).png
# The file has been deleted
#
# the first file is:
# Non-Covid (1078).png
# The file has been deleted
#
# the first file is:
# Non-Covid (697).png
# ...

# %%
counter()
# Out:
# The directory is  /home/shehroz/Desktop/Seminar/data_ct/non-COVID
# File count: 100

# %%
os.chdir('/home/shehroz/Desktop/Seminar/Viral Pneumonia/images')
print(os.getcwd())
# Out:
# /home/shehroz/Desktop/Seminar/Viral Pneumonia/images

# %%
counter()
# Out:
# The directory is  /home/shehroz/Desktop/Seminar/Viral Pneumonia/images
# File count: 1345

# %%
for _ in range(1245):
    deleter()
counter()
# Out:
# the first file is:
# Viral Pneumonia-1317.png
# The file has been deleted
#
# the first file is:
# Viral Pneumonia-602.png
# The file has been deleted
#
# the first file is:
# Viral Pneumonia-1197.png
# The file has been deleted
#
# the first file is:
# Viral Pneumonia-702.png
# The file has been deleted
#
# the first file is:
# Viral Pneumonia-820.png
# The file has been deleted
#
# the first file is:
# Viral Pneumonia-911.png
# The file has been deleted
#
# the first file is:
# Viral Pneumonia-1059.png
# The file has been deleted
#
# the first file is:
# Viral Pneumonia-187.png
# The file has been deleted
#
# the first file is:
# Viral Pneumonia-338.png
# The file has been deleted
#
# the first file is:
# Viral Pneumonia-109.png
# The file has been deleted
#
# the first file is:
# Viral Pneumonia-185.png
# The file has been deleted
#
# the first file is:
# Viral Pneumonia-58.png
# The file has been deleted
#
# the first file is:
# Viral Pneumonia-849.png
# ...
