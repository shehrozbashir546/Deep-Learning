# %%
# !conda list
# Out:
# # packages in environment at /home/shehroz/miniconda3/envs/fAi:
# #
# # Name                    Version                   Build  Channel
# _libgcc_mutex             0.1                        main
# _openmp_mutex             5.1                       1_gnu
# asttokens                 2.0.5              pyhd3eb1b0_0    anaconda
# astunparse                1.6.3                    pypi_0    pypi
# backcall                  0.2.0              pyhd3eb1b0_0    anaconda
# blas                      1.0                         mkl
# bottleneck                1.3.5           py310ha9d4c09_0
# brotli                    1.0.9                h5eee18b_7
# brotli-bin                1.0.9                h5eee18b_7
# brotlipy                  0.7.0           py310h7f8727e_1002
# bzip2                     1.0.8                h7b6447c_0
# ca-certificates           2022.07.19           h06a4308_0    anaconda
# catalogue                 2.0.7           py310h06a4308_0
# ...

# %%
# !conda install cudatoolkit=11.2 cudnn=8.1 -c=conda-forge -y
# Out:
# ...
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/shehroz/miniconda3/envs/fAi
#
#   added / updated specs:
#     - cudatoolkit=11.2
#     - cudnn=8.1
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     certifi-2022.9.24          |     pyhd8ed1ab_0         155 KB  conda-forge
#     cudatoolkit-11.2.2         |      hbe64b41_10       876.8 MB  conda-forge
#     cudnn-8.1.0.77             |       h90431f1_0       634.8 MB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        1.48 GB
#
# The following NEW packages will be INSTALLED:
#
#   cudatoolkit        conda-forge/linux-64::cudatoolkit-11.2.2-hbe64b41_10 None
# ...

# %%
# !pip install --upgrade tensorflow-gpu==2.11.0
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 588.3/588.3 MB 3.9 MB/s eta 0:00:00m eta 0:00:010:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 20.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 439.2/439.2 kB 44.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 27.6 MB/s eta 0:00:00m eta 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 25.5 MB/s eta 0:00:00m eta 0:00:010:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 27.4 MB/s eta 0:00:00m eta 0:00:010:01:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 29.3 MB/s eta 0:00:00 MB/s eta 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.5/65.5 kB 13.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.6/124.6 kB 23.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 14.4 MB/s eta 0:00:00
# ...

# %%
import tensorflow as tf
tf.config.list_physical_devices('GPU')
# Out:
# []

# %%
# !pip install keras
